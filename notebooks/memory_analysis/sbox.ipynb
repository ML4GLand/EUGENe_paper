# %%
import seqdata as sd
import seqpro as sp
import torch

# %%
file = '/cellar/users/dlaub/projects/ML4GLand/EUGENe_paper/scripts/training_mem/data/sdata_n=1000_l=10000000.zarr'
sdata = sd.open_zarr(file)
sdata
# Out:
# <xarray.Dataset>
# Dimensions:  (_sequence: 1000, _length: 10000000)
# Dimensions without coordinates: _sequence, _length
# Data variables:
#     seq      (_sequence, _length) |S1 dask.array<chunksize=(214, 10000000), meta=np.ndarray>
# Attributes:
#     length_dim:    _length
#     max_jitter:    0
#     sequence_dim:  _sequence

# %%
transforms = {
    "seq": lambda x: torch.tensor(
        sp.ohe(x, alphabet=sp.alphabets.DNA), dtype=torch.float32
    )
}
dl = sd.get_torch_dataloader(
    sdata,
    sample_dims='_sequence',
    variables='seq',
    transforms=transforms,
    batch_size=128
)

# %%
batch = next(iter(dl))
# Out:
# /cellar/users/dlaub/miniconda3/envs/eugene-dev/lib/python3.9/site-packages/xarray/core/indexing.py:1443: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]

# %%
batch['seq'].size()
# Out:
# torch.Size([128, 10000000, 4])

# %%
int(1028**3) / 1e9
# Out:
# 1.086373952
